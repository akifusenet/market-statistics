# %%
import numpy as np
import pandas as pd

M30_File = "EURUSD_m30_2003_2020_NY.csv"
df = pd.read_csv(M30_File, header=0)

# Generate a compound column DateTime consisting of date+timestamp
df.loc[:,'DateTime'] = pd.to_datetime(df.Date.astype(str)+' '+df.Timestamp.astype(str))

print(df.head())
print('\n')
print('Rows:', df.shape[0])


#df.head()
# Out:
#        Date Timestamp     Open     High      Low    Close        Volume  \
# 0  20030505  03:00:00  1.12161  1.12258  1.12154  1.12218  15695.100021
# 1  20030505  03:30:00  1.12207  1.12314  1.12198  1.12258  14219.700005
# 2  20030505  04:00:00  1.12232  1.12262  1.12153  1.12180  14562.499998
# 3  20030505  04:30:00  1.12170  1.12209  1.12099  1.12140  13808.200030
# 4  20030505  05:00:00  1.12141  1.12211  1.12116  1.12190  14526.200005
#
#              DateTime
# 0 2003-05-05 03:00:00
# 1 2003-05-05 03:30:00
# 2 2003-05-05 04:00:00
# 3 2003-05-05 04:30:00
# 4 2003-05-05 05:00:00
#
#
# Rows: 209098

# %%
import numpy as np
import pandas as pd

Profile1_File = "ProfileData/Overlay-1Days-PriceSteps-2.MinDistPrices-4.MinDistTPOs-3.csv"
Profile3_File = "ProfileData/Overlay-3Days-PriceSteps-2.MinDistPrices-4.MinDistTPOs-3.csv"
Profile5_File = "ProfileData/Overlay-5Days-PriceSteps-2.MinDistPrices-4.MinDistTPOs-3.csv"
Profile10_File = "ProfileData/Overlay-10Days-PriceSteps-2.MinDistPrices-4.MinDistTPOs-3.csv"
Profile20_File = "ProfileData/Overlay-20Days-PriceSteps-2.MinDistPrices-4.MinDistTPOs-5.csv"

p1 = pd.read_csv(Profile1_File, header=0)
p1['Datetime']=pd.to_datetime(p1['End Time'])
p3 = pd.read_csv(Profile3_File, header=0)
p3['Datetime']=pd.to_datetime(p3['End Time'])
p5 = pd.read_csv(Profile5_File, header=0)
p5['Datetime']=pd.to_datetime(p5['End Time'])
p10 = pd.read_csv(Profile10_File, header=0)
p10['Datetime']=pd.to_datetime(p10['End Time'])
p20 = pd.read_csv(Profile20_File, header=0)
p20['Datetime']=pd.to_datetime(p20['End Time'])

pr20EndTime = p20['End Time'][0]

indexNames1 = p1[ p1['End Time'] < pr20EndTime ].index
p1.drop(indexNames1 , inplace=True)
indexNames3 = p3[ p3['End Time'] < pr20EndTime ].index
p3.drop(indexNames3 , inplace=True)
indexNames5 = p5[ p5['End Time'] < pr20EndTime ].index
p5.drop(indexNames5 , inplace=True)
indexNames10 = p10[ p10['End Time'] < pr20EndTime ].index
p10.drop(indexNames10 , inplace=True)


#print(p1.dtypes)
#print(p1['Dist(s)1'].describe())

#print('p1:', p1.shape)
#print('p3:', p3.shape)
#print('p5:', p5.shape)
#print('p10:', p10.shape)
#print('p20:', p20.shape)

#print(p1.head())
#print(p5.head())



commonDict = { 
    'Datetime': p5['Datetime'],
    'Start Time5': p5['Start Time'],
    'Bracket UL5': p5['Bracket UL'],               
    'Bracket UO5': p5['Bracket UO'],               
    'Bracket UQ5': p5['Bracket UQ'],               
    'Bracket MID5': p5['Bracket MID']               
             }  
commonDF = pd.DataFrame(commonDict) 
print(commonDF.head(10))

print(df.head())
print('\n')
print('Rows:', df.shape[0])
# Out:
#     Bracket MID5  Bracket UL5  Bracket UO5  Bracket UQ5            Datetime  \
# 15        1.1785       1.1908      1.18773      1.18465 2003-06-03 23:30:00
# 16        1.1784       1.1908      1.18770      1.18460 2003-06-04 23:30:00
# 17        1.1769       1.1908      1.18732      1.18385 2003-06-05 23:30:00
# 18        1.1754       1.1878      1.18470      1.18160 2003-06-06 23:30:00
# 19        1.1754       1.1878      1.18470      1.18160 2003-06-09 23:30:00
# 20        1.1754       1.1878      1.18470      1.18160 2003-06-10 23:30:00
# 21        1.1754       1.1878      1.18470      1.18160 2003-06-11 23:30:00
# 22        0.0000       0.0000      0.00000      0.00000 2003-06-12 23:30:00
# 23        0.0000       0.0000      0.00000      0.00000 2003-06-13 23:30:00
# 24        0.0000       0.0000      0.00000      0.00000 2003-06-16 23:30:00
#
#          Start Time5
# 15  2003.05.28 00:00
# 16  2003.05.29 00:00
# 17  2003.05.30 00:00
# 18  2003.06.02 00:00
# 19  2003.06.03 00:00
# 20  2003.06.04 00:00
# 21  2003.06.05 00:00
# 22  2003.06.06 00:00
# 23  2003.06.09 00:00
# 24  2003.06.10 00:00
#        Date Timestamp     Open     High      Low    Close        Volume  \
# 0  20030505  03:00:00  1.12161  1.12258  1.12154  1.12218  15695.100021
# 1  20030505  03:30:00  1.12207  1.12314  1.12198  1.12258  14219.700005
# 2  20030505  04:00:00  1.12232  1.12262  1.12153  1.12180  14562.499998
# 3  20030505  04:30:00  1.12170  1.12209  1.12099  1.12140  13808.200030
# 4  20030505  05:00:00  1.12141  1.12211  1.12116  1.12190  14526.200005
#
#              DateTime
# 0 2003-05-05 03:00:00
# 1 2003-05-05 03:30:00
# 2 2003-05-05 04:00:00
# 3 2003-05-05 04:30:00
# 4 2003-05-05 05:00:00
#
#
# Rows: 209098

# %%
import datetime

#datetime.datetime.now() + datetime.timedelta(days=1)
commonDFTail = commonDF.tail(5)
#commonDFTail['UL5Breakout']=0
commonDFTail.assign(UL5Breakout=0)
print("\ncommonDFTail:\n",commonDFTail)
for index, row in commonDFTail.iterrows():
    if (row['Bracket UL5']>0):        
        weekday = row['Datetime'].weekday()
        upperLevel5 = row['Bracket UL5']
        upperOctant5 = row['Bracket UO5']
        upperQuadrant5 = row['Bracket UQ5']
        mid5 = row['Bracket MID5']    
        dayAfter=df['DateTime']>row['Datetime']
        dful5=df[dayAfter]
        print(dful5.head())
# Out:
# commonDFTail:
#        Bracket MID5  Bracket UL5  Bracket UO5  Bracket UQ5            Datetime  \
# 4355        1.1067       1.1114      1.11023      1.10905 2020-01-24 23:30:00
# 4356        1.1062       1.1114      1.11010      1.10880 2020-01-27 23:30:00
# 4357        1.1049       1.1100      1.10873      1.10745 2020-01-28 23:30:00
# 4358        0.0000       0.0000      0.00000      0.00000 2020-01-29 23:30:00
# 4359        0.0000       0.0000      0.00000      0.00000 2020-01-30 01:30:00
#
#            Start Time5
# 4355  2020.01.20 00:00
# 4356  2020.01.21 00:00
# 4357  2020.01.22 00:00
# 4358  2020.01.23 00:00
# 4359  2020.01.24 00:00
#             Date Timestamp     Open     High      Low    Close       Volume  \
# 208950  20200127  00:00:00  1.10318  1.10321  1.10259  1.10293  2408.741998
# 208951  20200127  00:30:00  1.10294  1.10320  1.10246  1.10301  1490.209601
# 208952  20200127  01:00:00  1.10301  1.10343  1.10255  1.10340  4349.740017
# 208953  20200127  01:30:00  1.10340  1.10342  1.10244  1.10245  2687.830005
# 208954  20200127  02:00:00  1.10245  1.10348  1.10245  1.10340  2253.870007
#
#                   DateTime
# 208950 2020-01-27 00:00:00
# 208951 2020-01-27 00:30:00
# 208952 2020-01-27 01:00:00
# 208953 2020-01-27 01:30:00
# 208954 2020-01-27 02:00:00
#             Date Timestamp     Open     High      Low    Close       Volume  \
# 208998  20200128  00:00:00  1.10185  1.10200  1.10180  1.10198  1092.750003
# 208999  20200128  00:30:00  1.10197  1.10197  1.10166  1.10180  1007.680004
# 209000  20200128  01:00:00  1.10180  1.10203  1.10179  1.10183  1033.080004
# 209001  20200128  01:30:00  1.10182  1.10200  1.10180  1.10193   431.540001
# 209002  20200128  02:00:00  1.10193  1.10199  1.10182  1.10187   862.360000
#
#                   DateTime
# 208998 2020-01-28 00:00:00
# 208999 2020-01-28 00:30:00
# 209000 2020-01-28 01:00:00
# 209001 2020-01-28 01:30:00
# 209002 2020-01-28 02:00:00
#             Date Timestamp     Open     High      Low    Close       Volume  \
# 209046  20200129  00:00:00  1.10219  1.10244  1.10193  1.10229   863.939995
# 209047  20200129  00:30:00  1.10230  1.10246  1.10206  1.10219  1755.729999
# 209048  20200129  01:00:00  1.10217  1.10232  1.10207  1.10229   904.060000
# 209049  20200129  01:30:00  1.10229  1.10229  1.10212  1.10220   493.750001
# 209050  20200129  02:00:00  1.10220  1.10245  1.10202  1.10242  1100.160002
#
#                   DateTime
# 209046 2020-01-29 00:00:00
# 209047 2020-01-29 00:30:00
# 209048 2020-01-29 01:00:00
# 209049 2020-01-29 01:30:00
# 209050 2020-01-29 02:00:00
